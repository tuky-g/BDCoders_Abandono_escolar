# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
import time
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state=0)

# %%
#Importamos los datos

X_train = pd.read_csv("./DatosAbandonoSinNan/X_train.csv", sep=',', decimal='.')
y_train = pd.read_csv("./DatosAbandonoSinNan/y_train.csv", sep=',', decimal='.')
X_val = pd.read_csv("./DatosAbandonoSinNan/X_val.csv", sep=',', decimal='.')
y_val = pd.read_csv("./DatosAbandonoSinNan/y_val.csv", sep=',', decimal='.')
X_test = pd.read_csv("./DatosAbandonoSinNan/X_test.csv", sep=',', decimal='.')
y_test = pd.read_csv("./DatosAbandonoSinNan/y_test.csv", sep=',', decimal='.')

features = X_train.columns

# %%
# from sklearn import preprocessing

# scaler = preprocessing.StandardScaler().fit(X_train)
# #scaler = preprocessing.Normalizer().fit(X_train)
# X_train = scaler.transform(X_train)
# X_val = scaler.transform(X_val)
# X_test = scaler.transform(X_test)

# %%
start_time = time.time()

dt = DecisionTreeClassifier(random_state = 0)

gs_dt = GridSearchCV(dt,
                    param_grid = {"max_depth" : range(2, 10), 
                                  "min_samples_split": range(4, 10, 2)},
                    scoring = None,
                    cv = 5)
gs_dt.fit(X_train, y_train)
gs_dt.best_estimator_

end_time = time.time()
print("Tiempo: ", end_time - start_time)
# Out:
# Tiempo:  26.534847021102905

# %%
pd.DataFrame(gs_dt.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.085787      0.001157         0.002780        0.000439
# 1        0.085029      0.000408         0.002942        0.000208
# 2        0.083958      0.000620         0.003074        0.000321
# 3        0.122149      0.000426         0.002406        0.000490
# 4        0.125524      0.002250         0.002621        0.000503
# 5        0.122081      0.000601         0.003071        0.000124
# 6        0.158921      0.001123         0.002611        0.000495
# 7        0.158129      0.000622         0.002307        0.000402
# 8        0.156996      0.000799         0.002708        0.000400
# 9        0.193476      0.000348         0.002608        0.000491
# 10       0.194872      0.002034         0.003227        0.000585
# 11       0.195093      0.001567         0.002910        0.000442
# 12       0.242622      0.005039         0.002409        0.000579
# 13       0.240809      0.003786         0.003484        0.001978
# 14       0.235837      0.004542         0.003312        0.000764
# 15       0.285194      0.008394         0.005181        0.004475
# 16       0.271884      0.005294         0.002225        0.001244
# 17       0.272901      0.003460         0.003005        0.000554
# 18       0.312878      0.002148         0.002978        0.000234
# 19       0.311828      0.001675         0.002677        0.000210
# 20       0.308679      0.001040         0.002981        0.000528
# 21       0.344300      0.001450         0.003169        0.000323
# 22       0.344671      0.002529         0.002607        0.000491
# 23       0.345385      0.003644         0.002764        0.000388
#
#    param_max_depth param_min_samples_split  \
# 0                2                       4
# 1                2                       6
# 2                2                       8
# 3                3                       4
# 4                3                       6
# 5                3                       8
# 6                4                       4
# 7                4                       6
# 8                4                       8
# 9                5                       4
# 10               5                       6
# 11               5                       8
# 12               6                       4
# 13               6                       6
# 14               6                       8
# 15               7                       4
# 16               7                       6
# 17               7                       8
# 18               8                       4
# 19               8                       6
# 20               8                       8
# 21               9                       4
# 22               9                       6
# 23               9                       8
#
#                                       params  split0_test_score  \
# 0   {'max_depth': 2, 'min_samples_split': 4}           0.974317
# 1   {'max_depth': 2, 'min_samples_split': 6}           0.974317
# 2   {'max_depth': 2, 'min_samples_split': 8}           0.974317
# 3   {'max_depth': 3, 'min_samples_split': 4}           0.974646
# 4   {'max_depth': 3, 'min_samples_split': 6}           0.974646
# 5   {'max_depth': 3, 'min_samples_split': 8}           0.974646
# 6   {'max_depth': 4, 'min_samples_split': 4}           0.972670
# 7   {'max_depth': 4, 'min_samples_split': 6}           0.972670
# 8   {'max_depth': 4, 'min_samples_split': 8}           0.972670
# 9   {'max_depth': 5, 'min_samples_split': 4}           0.971353
# 10  {'max_depth': 5, 'min_samples_split': 6}           0.971353
# 11  {'max_depth': 5, 'min_samples_split': 8}           0.971353
# 12  {'max_depth': 6, 'min_samples_split': 4}           0.970695
# 13  {'max_depth': 6, 'min_samples_split': 6}           0.971024
# 14  {'max_depth': 6, 'min_samples_split': 8}           0.971353
# 15  {'max_depth': 7, 'min_samples_split': 4}           0.967402
# 16  {'max_depth': 7, 'min_samples_split': 6}           0.968390
# 17  {'max_depth': 7, 'min_samples_split': 8}           0.969707
# 18  {'max_depth': 8, 'min_samples_split': 4}           0.966414
# 19  {'max_depth': 8, 'min_samples_split': 6}           0.967073
# 20  {'max_depth': 8, 'min_samples_split': 8}           0.968061
# 21  {'max_depth': 9, 'min_samples_split': 4}           0.963451
# 22  {'max_depth': 9, 'min_samples_split': 6}           0.965756
# 23  {'max_depth': 9, 'min_samples_split': 8}           0.966414
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.974317           0.974317           0.973000
# 1            0.974317           0.974317           0.973000
# 2            0.974317           0.974317           0.973000
# 3            0.974317           0.973000           0.972670
# 4            0.974317           0.973000           0.972670
# 5            0.974317           0.973000           0.972670
# 6            0.973987           0.970036           0.970695
# 7            0.973987           0.970036           0.970695
# 8            0.973987           0.970036           0.970695
# 9            0.971024           0.967731           0.970365
# 10           0.971683           0.967402           0.970036
# 11           0.971683           0.967402           0.970036
# 12           0.970695           0.969378           0.971024
# 13           0.971683           0.968719           0.970695
# 14           0.971353           0.968719           0.970695
# 15           0.969707           0.966743           0.971024
# 16           0.969048           0.967073           0.971024
# 17           0.969707           0.968390           0.971024
# 18           0.968061           0.964439           0.971683
# 19           0.967402           0.964439           0.971024
# 20           0.968061           0.964439           0.970695
# 21           0.968061           0.964439           0.970036
# 22           0.969378           0.963451           0.970036
# 23           0.968719           0.965097           0.970365
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.974638         0.974118        0.000573                1
# 1            0.974638         0.974118        0.000573                1
# 2            0.974638         0.974118        0.000573                1
# 3            0.974967         0.973920        0.000915                4
# 4            0.974967         0.973920        0.000915                4
# 5            0.974967         0.973920        0.000915                4
# 6            0.973320         0.972142        0.001523                9
# 7            0.973650         0.972208        0.001579                7
# 8            0.973650         0.972208        0.001579                7
# 9            0.971344         0.970364        0.001364               11
# 10           0.971344         0.970364        0.001585               11
# 11           0.971673         0.970429        0.001630               10
# 12           0.968709         0.970100        0.000896               15
# 13           0.969368         0.970298        0.001092               13
# 14           0.969368         0.970298        0.001072               13
# 15           0.966403         0.968256        0.001801               18
# 16           0.968379         0.968783        0.001291               17
# 17           0.968050         0.969376        0.001064               16
# 18           0.963109         0.966741        0.002992               23
# 19           0.965415         0.967070        0.002254               19
# 20           0.963768         0.967005        0.002565               21
# 21           0.964097         0.966017        0.002573               24
# 22           0.965086         0.966741        0.002544               22
# 23           0.964427         0.967005        0.002230               20

# %%
gs_dt.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_split=4, random_state=0)

# %%
gs_dt.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 0,
#  'splitter': 'best'}

# %%
start_time = time.time()

rf = RandomForestClassifier(random_state=0)
gs_rf = GridSearchCV(rf,
                    param_grid = {"max_depth": range(2,6), "min_samples_split": range(4,6,2), "n_estimators": range(100, 251, 50)},
                    scoring = None,
                    cv = 5)
gs_rf.fit(X_train, y_train)

end_time = time.time()
print("Tiempo: ", end_time - start_time)
# Out:
# Tiempo:  253.3712830543518

# %%
pd.DataFrame(gs_rf.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.080569      0.009468         0.017676        0.000368
# 1        1.617363      0.017910         0.024715        0.000260
# 2        2.186870      0.027052         0.033929        0.002819
# 3        2.731296      0.030261         0.039132        0.000746
# 4        1.550694      0.006610         0.018464        0.000429
# 5        2.325702      0.018467         0.026279        0.000269
# 6        3.101025      0.009311         0.033710        0.001145
# 7        3.880586      0.023290         0.041526        0.000350
# 8        2.012155      0.011163         0.019554        0.000583
# 9        2.972785      0.012348         0.027960        0.001264
# 10       4.090561      0.185440         0.034890        0.002644
# 11       4.972623      0.020893         0.043379        0.000897
# 12       2.452927      0.029528         0.021903        0.002754
# 13       3.669334      0.029669         0.028783        0.000643
# 14       4.893334      0.029090         0.037053        0.000464
# 15       6.120964      0.020657         0.045871        0.000581
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 0                2                       4                100
# 1                2                       4                150
# 2                2                       4                200
# 3                2                       4                250
# 4                3                       4                100
# 5                3                       4                150
# 6                3                       4                200
# 7                3                       4                250
# 8                4                       4                100
# 9                4                       4                150
# 10               4                       4                200
# 11               4                       4                250
# 12               5                       4                100
# 13               5                       4                150
# 14               5                       4                200
# 15               5                       4                250
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 1   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 2   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 3   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 4   {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 5   {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 6   {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 7   {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 8   {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 9   {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 10  {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 11  {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 12  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 13  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 14  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 15  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.974317           0.974317           0.974317
# 1            0.974317           0.974317           0.974317
# 2            0.974317           0.974317           0.974317
# 3            0.974317           0.974317           0.974317
# 4            0.974317           0.974317           0.974317
# 5            0.974317           0.974317           0.974317
# 6            0.974317           0.974317           0.974317
# 7            0.974317           0.974317           0.974317
# 8            0.974317           0.974317           0.974646
# 9            0.974317           0.974317           0.974317
# 10           0.974317           0.974317           0.974317
# 11           0.974317           0.974317           0.974317
# 12           0.973987           0.973987           0.974646
# 13           0.973987           0.973987           0.974646
# 14           0.973987           0.973987           0.974646
# 15           0.973987           0.974317           0.974646
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.974638         0.974381        0.000128                2
# 1            0.974638         0.974381        0.000128                2
# 2            0.974638         0.974381        0.000128                2
# 3            0.974638         0.974381        0.000128                2
# 4            0.974638         0.974381        0.000128                2
# 5            0.974638         0.974381        0.000128                2
# 6            0.974638         0.974381        0.000128                2
# 7            0.974638         0.974381        0.000128                2
# 8            0.974638         0.974447        0.000159                1
# 9            0.974638         0.974381        0.000128                2
# 10           0.974638         0.974381        0.000128                2
# 11           0.974638         0.974381        0.000128                2
# 12           0.974638         0.974315        0.000293               14
# 13           0.974638         0.974315        0.000293               14
# 14           0.974638         0.974315        0.000293               14
# 15           0.974638         0.974381        0.000245                2

# %%
gs_rf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=4, min_samples_split=4, random_state=0)

# %%
gs_rf.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
start_time = time.time()

et = ExtraTreesClassifier(random_state=0)
gs_et = GridSearchCV(et,
                    param_grid = {"max_depth": range(2,6), "min_samples_split": range(4,10,2), "n_estimators": range(100, 251, 50)},
                    scoring = None,
                    cv = 5)
gs_et.fit(X_train, y_train)

end_time = time.time()
print("Tiempo: ", end_time - start_time)
# Out:
# Tiempo:  105.13435196876526

# %%
pd.DataFrame(gs_et.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.183399      0.006729         0.019043        0.001040
# 1        0.267990      0.008485         0.026212        0.000819
# 2        0.356442      0.007260         0.034605        0.001328
# 3        0.434959      0.009935         0.040393        0.000902
# 4        0.177031      0.002759         0.018191        0.000554
# 5        0.266065      0.004658         0.025830        0.000359
# 6        0.353237      0.011140         0.033129        0.000491
# 7        0.428886      0.005412         0.039668        0.000583
# 8        0.178219      0.002953         0.018463        0.000534
# 9        0.259434      0.005574         0.025668        0.000461
# 10       0.343920      0.005538         0.032852        0.000414
# 11       0.434278      0.013413         0.039914        0.000736
# 12       0.210776      0.001260         0.019364        0.000286
# 13       0.313914      0.005833         0.027406        0.000397
# 14       0.419158      0.008767         0.035515        0.000680
# 15       0.520868      0.013552         0.043051        0.000518
# 16       0.215381      0.008216         0.019584        0.000820
# 17       0.323748      0.011601         0.027800        0.001026
# 18       0.424079      0.010007         0.035725        0.000875
# 19       0.524128      0.007768         0.044021        0.001124
# 20       0.213167      0.006463         0.019307        0.000718
# 21       0.317338      0.007763         0.027170        0.000393
# 22       0.419571      0.008389         0.035745        0.000574
# 23       0.533153      0.017054         0.043460        0.000552
# 24       0.255194      0.011128         0.020654        0.000543
# 25       0.375139      0.008499         0.029727        0.000540
# 26       0.496242      0.008746         0.038431        0.000319
# 27       0.615179      0.008119         0.046628        0.000713
# 28       0.264537      0.018984         0.021022        0.000664
# 29       0.385278      0.012351         0.029346        0.000330
# 30       0.505524      0.017026         0.038165        0.000917
# 31       0.607999      0.012423         0.046605        0.000192
# 32       0.248517      0.002904         0.020781        0.000907
# 33       0.385679      0.022304         0.028863        0.000769
# 34       0.495948      0.011733         0.037547        0.000505
# 35       0.630985      0.017330         0.046640        0.000539
# 36       0.286391      0.003348         0.021711        0.000372
# 37       0.459957      0.031767         0.031211        0.000514
# 38       0.554113      0.012015         0.040186        0.000644
# 39       0.681236      0.003923         0.049627        0.000474
# 40       0.291255      0.005974         0.022253        0.000310
# 41       0.419952      0.011719         0.031149        0.000456
# 42       0.517760      0.010380         0.039207        0.005012
# 43       0.695914      0.026766         0.051256        0.001508
# 44       0.302087      0.010663         0.020795        0.002858
# 45       0.460491      0.028422         0.032022        0.000616
# 46       0.587497      0.034678         0.040975        0.000833
# 47       0.706376      0.018722         0.049207        0.001313
#
#    param_max_depth param_min_samples_split param_n_estimators  \
# 0                2                       4                100
# 1                2                       4                150
# 2                2                       4                200
# 3                2                       4                250
# 4                2                       6                100
# 5                2                       6                150
# 6                2                       6                200
# 7                2                       6                250
# 8                2                       8                100
# 9                2                       8                150
# 10               2                       8                200
# 11               2                       8                250
# 12               3                       4                100
# 13               3                       4                150
# 14               3                       4                200
# 15               3                       4                250
# 16               3                       6                100
# 17               3                       6                150
# 18               3                       6                200
# 19               3                       6                250
# 20               3                       8                100
# 21               3                       8                150
# 22               3                       8                200
# 23               3                       8                250
# 24               4                       4                100
# 25               4                       4                150
# 26               4                       4                200
# 27               4                       4                250
# 28               4                       6                100
# 29               4                       6                150
# 30               4                       6                200
# 31               4                       6                250
# 32               4                       8                100
# 33               4                       8                150
# 34               4                       8                200
# 35               4                       8                250
# 36               5                       4                100
# 37               5                       4                150
# 38               5                       4                200
# 39               5                       4                250
# 40               5                       6                100
# 41               5                       6                150
# 42               5                       6                200
# 43               5                       6                250
# 44               5                       8                100
# 45               5                       8                150
# 46               5                       8                200
# 47               5                       8                250
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 1   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 2   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 3   {'max_depth': 2, 'min_samples_split': 4, 'n_es...           0.974317
# 4   {'max_depth': 2, 'min_samples_split': 6, 'n_es...           0.974317
# 5   {'max_depth': 2, 'min_samples_split': 6, 'n_es...           0.974317
# 6   {'max_depth': 2, 'min_samples_split': 6, 'n_es...           0.974317
# 7   {'max_depth': 2, 'min_samples_split': 6, 'n_es...           0.974317
# 8   {'max_depth': 2, 'min_samples_split': 8, 'n_es...           0.974317
# 9   {'max_depth': 2, 'min_samples_split': 8, 'n_es...           0.974317
# 10  {'max_depth': 2, 'min_samples_split': 8, 'n_es...           0.974317
# 11  {'max_depth': 2, 'min_samples_split': 8, 'n_es...           0.974317
# 12  {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 13  {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 14  {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 15  {'max_depth': 3, 'min_samples_split': 4, 'n_es...           0.974317
# 16  {'max_depth': 3, 'min_samples_split': 6, 'n_es...           0.974317
# 17  {'max_depth': 3, 'min_samples_split': 6, 'n_es...           0.974317
# 18  {'max_depth': 3, 'min_samples_split': 6, 'n_es...           0.974317
# 19  {'max_depth': 3, 'min_samples_split': 6, 'n_es...           0.974317
# 20  {'max_depth': 3, 'min_samples_split': 8, 'n_es...           0.974317
# 21  {'max_depth': 3, 'min_samples_split': 8, 'n_es...           0.974317
# 22  {'max_depth': 3, 'min_samples_split': 8, 'n_es...           0.974317
# 23  {'max_depth': 3, 'min_samples_split': 8, 'n_es...           0.974317
# 24  {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 25  {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 26  {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 27  {'max_depth': 4, 'min_samples_split': 4, 'n_es...           0.974317
# 28  {'max_depth': 4, 'min_samples_split': 6, 'n_es...           0.974317
# 29  {'max_depth': 4, 'min_samples_split': 6, 'n_es...           0.974317
# 30  {'max_depth': 4, 'min_samples_split': 6, 'n_es...           0.974317
# 31  {'max_depth': 4, 'min_samples_split': 6, 'n_es...           0.974317
# 32  {'max_depth': 4, 'min_samples_split': 8, 'n_es...           0.974317
# 33  {'max_depth': 4, 'min_samples_split': 8, 'n_es...           0.974317
# 34  {'max_depth': 4, 'min_samples_split': 8, 'n_es...           0.974317
# 35  {'max_depth': 4, 'min_samples_split': 8, 'n_es...           0.974317
# 36  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 37  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 38  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 39  {'max_depth': 5, 'min_samples_split': 4, 'n_es...           0.974317
# 40  {'max_depth': 5, 'min_samples_split': 6, 'n_es...           0.974317
# 41  {'max_depth': 5, 'min_samples_split': 6, 'n_es...           0.974317
# 42  {'max_depth': 5, 'min_samples_split': 6, 'n_es...           0.974317
# 43  {'max_depth': 5, 'min_samples_split': 6, 'n_es...           0.974317
# 44  {'max_depth': 5, 'min_samples_split': 8, 'n_es...           0.974317
# 45  {'max_depth': 5, 'min_samples_split': 8, 'n_es...           0.974317
# 46  {'max_depth': 5, 'min_samples_split': 8, 'n_es...           0.974317
# 47  {'max_depth': 5, 'min_samples_split': 8, 'n_es...           0.974317
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.974317           0.974317           0.974317
# 1            0.974317           0.974317           0.974317
# 2            0.974317           0.974317           0.974317
# 3            0.974317           0.974317           0.974317
# 4            0.974317           0.974317           0.974317
# 5            0.974317           0.974317           0.974317
# 6            0.974317           0.974317           0.974317
# 7            0.974317           0.974317           0.974317
# 8            0.974317           0.974317           0.974317
# 9            0.974317           0.974317           0.974317
# 10           0.974317           0.974317           0.974317
# 11           0.974317           0.974317           0.974317
# 12           0.974317           0.974317           0.974317
# 13           0.974317           0.974317           0.974317
# 14           0.974317           0.974317           0.974317
# 15           0.974317           0.974317           0.974317
# 16           0.974317           0.974317           0.974317
# 17           0.974317           0.974317           0.974317
# 18           0.974317           0.974317           0.974317
# 19           0.974317           0.974317           0.974317
# 20           0.974317           0.974317           0.974317
# 21           0.974317           0.974317           0.974317
# 22           0.974317           0.974317           0.974317
# 23           0.974317           0.974317           0.974317
# 24           0.974317           0.974317           0.974317
# 25           0.974317           0.974317           0.974317
# 26           0.974317           0.974317           0.974317
# 27           0.974317           0.974317           0.974317
# 28           0.974317           0.974317           0.974317
# 29           0.974317           0.974317           0.974317
# 30           0.974317           0.974317           0.974317
# 31           0.974317           0.974317           0.974317
# 32           0.974317           0.974317           0.974317
# 33           0.974317           0.974317           0.974317
# 34           0.974317           0.974317           0.974317
# 35           0.974317           0.974317           0.974317
# 36           0.974317           0.974317           0.974646
# 37           0.974317           0.974317           0.974317
# 38           0.974317           0.974317           0.974317
# 39           0.974317           0.974317           0.974317
# 40           0.974317           0.974317           0.974646
# 41           0.974317           0.974317           0.974317
# 42           0.974317           0.974317           0.974317
# 43           0.974317           0.974317           0.974317
# 44           0.974317           0.974317           0.974317
# 45           0.974317           0.974317           0.974317
# 46           0.974317           0.974317           0.974317
# 47           0.974317           0.974317           0.974317
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.974638         0.974381        0.000128                3
# 1            0.974638         0.974381        0.000128                3
# 2            0.974638         0.974381        0.000128                3
# 3            0.974638         0.974381        0.000128                3
# 4            0.974638         0.974381        0.000128                3
# 5            0.974638         0.974381        0.000128                3
# 6            0.974638         0.974381        0.000128                3
# 7            0.974638         0.974381        0.000128                3
# 8            0.974638         0.974381        0.000128                3
# 9            0.974638         0.974381        0.000128                3
# 10           0.974638         0.974381        0.000128                3
# 11           0.974638         0.974381        0.000128                3
# 12           0.974638         0.974381        0.000128                3
# 13           0.974638         0.974381        0.000128                3
# 14           0.974638         0.974381        0.000128                3
# 15           0.974638         0.974381        0.000128                3
# 16           0.974638         0.974381        0.000128                3
# 17           0.974638         0.974381        0.000128                3
# 18           0.974638         0.974381        0.000128                3
# 19           0.974638         0.974381        0.000128                3
# 20           0.974638         0.974381        0.000128                3
# 21           0.974638         0.974381        0.000128                3
# 22           0.974638         0.974381        0.000128                3
# 23           0.974638         0.974381        0.000128                3
# 24           0.974638         0.974381        0.000128                3
# 25           0.974638         0.974381        0.000128                3
# 26           0.974638         0.974381        0.000128                3
# 27           0.974638         0.974381        0.000128                3
# 28           0.974638         0.974381        0.000128                3
# 29           0.974638         0.974381        0.000128                3
# 30           0.974638         0.974381        0.000128                3
# 31           0.974638         0.974381        0.000128                3
# 32           0.974638         0.974381        0.000128                3
# 33           0.974638         0.974381        0.000128                3
# 34           0.974638         0.974381        0.000128                3
# 35           0.974638         0.974381        0.000128                3
# 36           0.974638         0.974447        0.000159                1
# 37           0.974638         0.974381        0.000128                3
# 38           0.974638         0.974381        0.000128                3
# 39           0.974638         0.974381        0.000128                3
# 40           0.974638         0.974447        0.000159                1
# 41           0.974638         0.974381        0.000128                3
# 42           0.974638         0.974381        0.000128                3
# 43           0.974638         0.974381        0.000128                3
# 44           0.974638         0.974381        0.000128                3
# 45           0.974638         0.974381        0.000128                3
# 46           0.974638         0.974381        0.000128                3
# 47           0.974638         0.974381        0.000128                3

# %%
gs_et.best_estimator_
# Out:
# ExtraTreesClassifier(max_depth=5, min_samples_split=4, random_state=0)

# %%
gs_et.best_estimator_.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
print("DecisionTreeClassifier best score:", gs_dt.best_score_)
print("RandomForestClassifier best score:", gs_rf.best_score_)
print("ExtraTreesClassifier best score:", gs_et.best_score_)
# Out:
# DecisionTreeClassifier best score: 0.9741175263537147
# RandomForestClassifier best score: 0.9744467986619136
# ExtraTreesClassifier best score: 0.9744467986619136

# %%
grid_predictions_dt = gs_dt.predict(X_test)

# print classification report
print(classification_report(y_test, grid_predictions_dt))
print(confusion_matrix(y_test, grid_predictions_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4652
#            1       0.00      0.00      0.00       110
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.98      4768
#    macro avg       0.33      0.33      0.33      4768
# weighted avg       0.95      0.98      0.96      4768
#
# [[4652    0    0]
#  [ 110    0    0]
#  [   6    0    0]]

# %%
grid_predictions_rf = gs_rf.predict(X_test)

# print classification report
print(classification_report(y_test, grid_predictions_rf))
print(confusion_matrix(y_test, grid_predictions_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4652
#            1       0.00      0.00      0.00       110
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.98      4768
#    macro avg       0.33      0.33      0.33      4768
# weighted avg       0.95      0.98      0.96      4768
#
# [[4652    0    0]
#  [ 110    0    0]
#  [   6    0    0]]

# %%
grid_predictions_et = gs_et.predict(X_test)

# print classification report
print(classification_report(y_test, grid_predictions_et))
print(confusion_matrix(y_test, grid_predictions_et))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4652
#            1       0.00      0.00      0.00       110
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.98      4768
#    macro avg       0.33      0.33      0.33      4768
# weighted avg       0.95      0.98      0.96      4768
#
# [[4652    0    0]
#  [ 110    0    0]
#  [   6    0    0]]

# %%
from joblib import dump, load
dump(gs_dt, 'gs_dt.joblib') 
dump(gs_rf, 'gs_rf.joblib') 
dump(gs_et, 'gs_et.joblib')
# Out:
# ['gs_et.joblib']
