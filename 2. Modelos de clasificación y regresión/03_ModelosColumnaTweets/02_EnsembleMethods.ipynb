# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Importamos los datos

X_train = pd.read_csv("./DatosAbandonoSinPondSinNan/X_train.csv", sep=',', decimal='.')
y_train = pd.read_csv("./DatosAbandonoSinPondSinNan/y_train.csv", sep=',', decimal='.')
X_val = pd.read_csv("./DatosAbandonoSinPondSinNan/X_val.csv", sep=',', decimal='.')
y_val = pd.read_csv("./DatosAbandonoSinPondSinNan/y_val.csv", sep=',', decimal='.')
X_test = pd.read_csv("./DatosAbandonoSinPondSinNan/X_test.csv", sep=',', decimal='.')
y_test = pd.read_csv("./DatosAbandonoSinPondSinNan/y_test.csv", sep=',', decimal='.')


features = X_train.columns

# %% [markdown]
# ### Vemos si somos capaces de mejorar los algoritmos por defecto aplicando GridSearchCV

# %%
start_time = time.time()

dt = DecisionTreeClassifier(random_state = 0)

gs_dt = GridSearchCV(dt,
                    param_grid = {"max_depth" : range(2, 10), 
                                  "min_samples_split": range(4, 10, 2)},
                    scoring = None,
                    cv = 5)
gs_dt.fit(X_train, y_train)
gs_dt.best_estimator_

end_time = time.time()
print("Tiempo: ", end_time - start_time)
# Out:
# Tiempo:  27.132631301879883

# %%
gs_dt.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_split=4, random_state=0)

# %%
gs_dt.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 0,
#  'splitter': 'best'}

# %%
start_time = time.time()

rf = RandomForestClassifier(random_state=0)
gs_rf = GridSearchCV(rf,
                    param_grid = {"max_depth": range(2,6), "min_samples_split": range(4,6,2), "n_estimators": range(100, 251, 50)},
                    scoring = None,
                    cv = 5)
gs_rf.fit(X_train, y_train)

end_time = time.time()
print("Tiempo: ", end_time - start_time)
# Out:
# Tiempo:  253.33215975761414

# %%
gs_rf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=4, min_samples_split=4, random_state=0)

# %%
gs_rf.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
start_time = time.time()

et = ExtraTreesClassifier(random_state=0)
gs_et = GridSearchCV(et,
                    param_grid = {"max_depth": range(2,6), "min_samples_split": range(4,10,2), "n_estimators": range(100, 251, 50)},
                    scoring = None,
                    cv = 5)
gs_et.fit(X_train, y_train)

end_time = time.time()
print("Tiempo: ", end_time - start_time)
# Out:
# Tiempo:  101.22969317436218

# %%
gs_et.best_estimator_
# Out:
# ExtraTreesClassifier(max_depth=2, min_samples_split=4, random_state=0)

# %%
gs_et.best_estimator_.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 2,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
print("DecisionTreeClassifier best score:", gs_dt.best_score_)
print("RandomForestClassifier best score:", gs_rf.best_score_)
print("ExtraTreesClassifier best score:", gs_et.best_score_)
# Out:
# DecisionTreeClassifier best score: 0.9741175263537147
# RandomForestClassifier best score: 0.9744467986619136
# ExtraTreesClassifier best score: 0.9743809442002739

# %%
grid_predictions_dt = gs_dt.predict(X_test)

# print classification report
print(classification_report(y_test, grid_predictions_dt))
print(confusion_matrix(y_test, grid_predictions_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4652
#            1       0.00      0.00      0.00       110
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.98      4768
#    macro avg       0.33      0.33      0.33      4768
# weighted avg       0.95      0.98      0.96      4768
#
# [[4652    0    0]
#  [ 110    0    0]
#  [   6    0    0]]

# %%
grid_predictions_rf = gs_rf.predict(X_test)

# print classification report
print(classification_report(y_test, grid_predictions_rf))
print(confusion_matrix(y_test, grid_predictions_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4652
#            1       0.00      0.00      0.00       110
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.98      4768
#    macro avg       0.33      0.33      0.33      4768
# weighted avg       0.95      0.98      0.96      4768
#
# [[4652    0    0]
#  [ 110    0    0]
#  [   6    0    0]]

# %%
grid_predictions_et = gs_et.predict(X_test)

# print classification report
print(classification_report(y_test, grid_predictions_et))
print(confusion_matrix(y_test, grid_predictions_et))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4652
#            1       0.00      0.00      0.00       110
#            2       0.00      0.00      0.00         6
#
#     accuracy                           0.98      4768
#    macro avg       0.33      0.33      0.33      4768
# weighted avg       0.95      0.98      0.96      4768
#
# [[4652    0    0]
#  [ 110    0    0]
#  [   6    0    0]]

# %%
from joblib import dump, load
dump(gs_dt, 'gs_dt.joblib') 
dump(gs_rf, 'gs_rf.joblib') 
dump(gs_et, 'gs_et.joblib')
# Out:
# ['gs_et.joblib']

# %% [markdown]
# ### Decision Tree Classifier

# %%
start_time = time.time()

dt = DecisionTreeClassifier(
    ccp_alpha = 0.0,
    class_weight = None,
    criterion = 'gini',
    max_depth = 2,
    max_features = None,
    max_leaf_nodes = None,
    min_impurity_decrease = 0.0,
    min_samples_leaf = 1,
    min_samples_split = 4,
    min_weight_fraction_leaf = 0.0,
    random_state =  0,
    splitter = 'best')

dt_score = cross_val_score(dt, X_train, y_train, cv = 5).mean()
end_time = time.time()
print("Tiempo: ", end_time - start_time)
print("Score: ", dt_score)
# Out:
# Tiempo:  0.4801645278930664
# Score:  0.9741175263537147

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_split=4, random_state=0)

# %%
importances = dt.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]


plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %% [markdown]
# Esto es normal que ocurra porque el árbol de decisión no tiene encuenta nuestra variable para formar el árbol

# %% [markdown]
# ### Random Forest Classifier

# %%
start_time = time.time()

#rf = RandomForestClassifier(max_depth=5, min_samples_split=4, random_state=0) 
rf = RandomForestClassifier(
    bootstrap = True,
    ccp_alpha = 0.0,
    class_weight = None,
    criterion = 'gini',
    max_depth = 4,
    max_features = 'sqrt',
    max_leaf_nodes = None,
    max_samples = None,
    min_impurity_decrease = 0.0,
    min_samples_leaf = 1,
    min_samples_split = 4,
    min_weight_fraction_leaf = 0.0,
    n_estimators =  100,
    n_jobs = None,
    oob_score = False,
    random_state = 0,
    verbose = 0,
    warm_start = False)

rf_score = cross_val_score(rf, X_train, y_train, cv = 10).mean()
end_time = time.time()
print("Tiempo: ", end_time - start_time)
print("Score: ", rf_score)
# Out:
# Tiempo:  22.914106845855713
# Score:  0.974380985340713

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, min_samples_split=4, random_state=0)

# %%
importances = rf.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]


plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %%
valores = list(zip(importances[indices], features[indices]))

def clave_ordenacion(tupla):
  return (-tupla[0], tupla[1])

sorted(valores, key=clave_ordenacion)
# Out:
# [(1.0, 'ST001D01T'),
#  (0.6242116389004113, 'PV8RCUN'),
#  (0.4428529151989528, 'PV6RTSN'),
#  (0.3824703892240977, 'PV4RTML'),
#  (0.3812177034474591, 'PV1RCER'),
#  (0.3634522636400996, 'PV10RTSN'),
#  (0.344314926562593, 'PV6RCER'),
#  (0.3439430884445099, 'BSMJ'),
#  (0.34354795680267347, 'PV3RCER'),
#  (0.29365172075691603, 'PV9RTSN'),
#  (0.2860921852275608, 'PV3RTSN'),
#  (0.27205491735743237, 'PV1GLCM'),
#  (0.2437664833747313, 'PV9MATH'),
#  (0.2275140861281304, 'PV4RCLI'),
#  (0.20155799804534927, 'PV8RTSN'),
#  (0.1924510701039276, 'PV4RCER'),
#  (0.1875744832983731, 'PV7RCER'),
#  (0.1722346085956411, 'PV2RTSN'),
#  (0.1718763480147182, 'PV8RCLI'),
#  (0.16398854868613366, 'PV10RCLI'),
#  (0.15745218818362547, 'PV3READ'),
#  (0.1540049448369101, 'GCAWARE'),
#  (0.15303518235683244, 'PV10RCER'),
#  (0.1422288079940011, 'PV1RTML'),
#  (0.13200333116063032, 'PV8RCER'),
#  (0.1316974138222334, 'PV9RCLI'),
#  (0.12397577285679236, 'PV3RCUN'),
#  (0.1233660273442486, 'PV9READ'),
#  (0.11397604998496358, 'PV7RTML'),
#  (0.11212302822813118, 'GCSELFEFF'),
#  (0.10323523491780559, 'OCOD3'),
#  (0.10084131277543999, 'Score_pond'),
#  (0.09740451017466543, 'PV7RCUN'),
#  (0.09059489093173173, 'MASTGOAL'),
#  (0.07695580060211077, 'PV6RTML'),
#  (0.0733161332230388, 'PV5RCUN'),
#  (0.0668483874222978, 'PV5RTSN'),
#  (0.05653532937590011, 'PV10RTML'),
#  (0.05294586644512703, 'PV8RTML'),
#  (0.041862800345761814, 'CNTSCHID'),
#  (0.041683229163248674, 'SENWT')]

# %% [markdown]
# ### Extra Trees Classifier

# %%
start_time = time.time()

et = ExtraTreesClassifier( 
    bootstrap = False,
    ccp_alpha = 0.0,
    class_weight = None,
    criterion = 'gini',
    max_depth = 2,
    max_features = 'sqrt',
    max_leaf_nodes = None,
    max_samples = None,
    min_impurity_decrease = 0.0,
    min_samples_leaf = 1,
    min_samples_split = 4,
    min_weight_fraction_leaf = 0.0,
    n_estimators =  100,
    n_jobs = None,
    oob_score = False,
    random_state = 0,
    verbose = 0,
    warm_start = False)
 

et_score = cross_val_score(et, X_train, y_train, cv = 10).mean()
end_time = time.time()
print("Tiempo: ", end_time - start_time)
print("Score: ", et_score)
# Out:
# Tiempo:  2.0006635189056396
# Score:  0.9743809419726072

# %%
et.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(max_depth=2, min_samples_split=4, random_state=0)

# %%
importances = et.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]


plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()

# %%
valores = list(zip(importances[indices], features[indices]))

def clave_ordenacion(tupla):
  return (-tupla[0], tupla[1])

sorted(valores, key=clave_ordenacion)
# Out:
# [(1.0, 'ST001D01T'),
#  (0.9680503950361418, 'PV4RCER'),
#  (0.6942670991186842, 'PV9RCLI'),
#  (0.6681922240955506, 'PV3READ'),
#  (0.6662735040289064, 'PV4RTML'),
#  (0.6099909320997072, 'PV6RCER'),
#  (0.5672928401542042, 'PV9READ'),
#  (0.552382619110113, 'PV10RTSN'),
#  (0.46019182346130505, 'PV6RTSN'),
#  (0.4485756681956699, 'PV9RTSN'),
#  (0.44682649722347134, 'PV5RCUN'),
#  (0.43116354185621036, 'PV3RCER'),
#  (0.4145016410938014, 'PV10RCER'),
#  (0.38945665784806055, 'PV3RTSN'),
#  (0.38015631288916596, 'PV8RTML'),
#  (0.37629705988792994, 'PV5RTSN'),
#  (0.35378550130188136, 'PV8RCLI'),
#  (0.34873151155627147, 'PV2RTSN'),
#  (0.30092290466122296, 'PV8RCUN'),
#  (0.2924836272276181, 'PV4RCLI'),
#  (0.2761713065508882, 'PV6RTML'),
#  (0.2585899543132381, 'PV10RTML'),
#  (0.22560749561546498, 'PV7RCUN'),
#  (0.21960430055905097, 'PV1GLCM'),
#  (0.20919752525474683, 'PV1RCER'),
#  (0.20405958581798778, 'PV7RCER'),
#  (0.179578225363042, 'PV1RTML'),
#  (0.17820021854995283, 'PV3RCUN'),
#  (0.17657679173084134, 'PV7RTML'),
#  (0.1690314103380704, 'BSMJ'),
#  (0.12416506887915439, 'PV8RTSN'),
#  (0.0943908299441078, 'GCAWARE'),
#  (0.08775203764902686, 'PV8RCER'),
#  (0.08713961613863166, 'Score_pond'),
#  (0.07858413283719895, 'PV10RCLI'),
#  (0.07848186342540335, 'OCOD3'),
#  (0.07528690586911889, 'PV9MATH'),
#  (0.0315014941538608, 'MASTGOAL'),
#  (0.0, 'CNTSCHID'),
#  (0.0, 'GCSELFEFF'),
#  (0.0, 'SENWT')]

# %%
from joblib import dump, load
dump(dt, 'dt.joblib') 
dump(rf, 'rf.joblib') 
dump(et, 'et.joblib')
# Out:
# ['et.joblib']

# %%
#!pip install pipreqs

# %%
#!pip freeze > requirements.txt

# %%
#!pip freeze

# %%
""" %%writefile requirements.txt

apache-beam[gcp]==2.24.0
tensorflow
gensim==3.6.0
fsspec==0.8.4
gcsfs==0.7.1
numpy==1.20.0 """
# Out:
# ' %%writefile requirements.txt\n\napache-beam[gcp]==2.24.0\ntensorflow\ngensim==3.6.0\nfsspec==0.8.4\ngcsfs==0.7.1\nnumpy==1.20.0 '

# %%
#!pip install -r requirements.txt
